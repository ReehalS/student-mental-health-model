# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.optimizers import SGD

from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV, KFold

# add confusion matrix, f1 + auc score, precision/recall + roc curves

# %%
data = pd.read_csv('../Data/clean_df_engineering.csv')
data.drop(['Course'], axis=1, inplace=True)

data.head()
# Out:
#    Age  Gender  CGPA  Stress_Level  Depression_Score  Anxiety_Score  \
# 0   24       0  2.44             0                 3              0
# 1   22       0  3.62             3                 2              1
# 2   22       0  3.16             2                 1              5
# 3   25       0  3.48             2                 3              2
# 4   23       0  3.65             2                 5              1
#
#    Sleep_Quality  Physical_Activity  Diet_Quality  Social_Support  \
# 0            0.5                0.0           0.5             0.0
# 1            0.5                1.0           0.5             0.5
# 2            1.0                0.0           0.5             0.5
# 3            0.5                0.0           0.0             1.0
# 4            1.0                0.5           0.5             0.0
#
#    Relationship_Status  Substance_Use  Counseling_Service_Use  Family_History  \
# 0                  0.0            0.5                     0.5               0
# 1                  0.0            0.0                     1.0               1
# 2                  0.0            0.0                     0.0               0
# 3                  0.0            0.0                     0.5               0
# 4                  0.0            0.0                     0.0               1
#
#    Chronic_Illness  Financial_Stress  Extracurricular_Involvement  \
# 0                0                 3                          0.0
# 1                0                 5                          0.0
# 2                0                 3                          0.0
# 3                0                 2                          0.5
# 4                0                 0                          0.5
#
#    Semester_Credit_Load  Residence_Type
# 0                    27             0.0
# 1                    24             0.0
# 2                    21             0.0
# 3                    29             1.0
# 4                    19             1.0

# %%
features = ['Age', 'CGPA', 'Semester_Credit_Load', 'Anxiety_Score']
N_FEATURES = len(features)

# %%
BINARY_CLASSIFICATION = True
BINARY_ENCODE_THRESHOLD = 3 # values greater than this will be encoded as 1

# for multi-class classification:
N_CLASSES = len(data['Depression_Score'].unique())

# %%
# Define build_model function for KerasClassifier
# def build_model(num_layers, num_neurons, activation, dropout_rate, momentum, reg_method, reg_rate, learning_rate):
def build_model(num_layers, num_neurons, activation, momentum, reg_method, reg_rate, learning_rate):
    regularizer = l1(reg_rate) if reg_method=='l1' else l2(reg_rate)

    model = Sequential()

    # Input layer
    model.add(Input((N_FEATURES,)))
    # Hidden layers
    for _ in range(num_layers):
        model.add(Dense(num_neurons, activation=activation, kernel_regularizer=regularizer))
        # model.add(Dropout(dropout_rate))
    # Output layer
    if BINARY_CLASSIFICATION:
        model.add(Dense(1, activation='sigmoid')) # binary classification
    else:
        model.add(Dense(N_CLASSES, activation='softmax')) # multi-class classification

    optimizer = SGD(learning_rate=learning_rate, momentum=momentum)
    loss_string = 'binary_crossentropy' if BINARY_CLASSIFICATION else 'sparse_categorical_crossentropy'
    model.compile(loss=loss_string, optimizer=optimizer, metrics=['accuracy'])
    return model

# %% [markdown]
# ## engineering dataset

# %%
# Load dataset
X = data[features]

if BINARY_CLASSIFICATION:
    y = data['Depression_Score'].apply(lambda x: 1 if x > BINARY_ENCODE_THRESHOLD else 0)
else:
    y = data['Depression_Score']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=12, shuffle=True)

# Preprocess data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define parameters grid for grid search
param_grid = {
    # parameters for Sequential model
    'model__num_layers': [2, 3], # number of hidden layers
    'model__num_neurons': [32, 64],
    'model__dropout_rate': [0.2, 0.5],
    'model__momentum': [0.5, 0.9],
    'model__activation': ['relu', 'tanh'],
    'model__reg_method': ['l1', 'l2'],
    'model__reg_rate': [0.001, 0.01, 0.1],
    'model__learning_rate': [0.001, 0.01, 0.1],
    # parameters for KerasClassifier
    'batch_size': [32, 64]
}

# Create KerasClassifier wrapper for scikit-learn
model = KerasClassifier(build_fn=build_model, epochs=10, verbose=1)

# Perform grid search with cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=kfold, scoring='accuracy')
grid_result = grid_search.fit(X_train, y_train)
# Out:
# c:\repos\ECS171FQ24_ResearchProject_SATAK\.venv\Lib\site-packages\joblib\externals\loky\process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# c:\repos\ECS171FQ24_ResearchProject_SATAK\.venv\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\repos\ECS171FQ24_ResearchProject_SATAK\.venv\Lib\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# Epoch 1/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6940 - loss: 1.3467
# Epoch 2/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7173 - loss: 1.3377
# Epoch 3/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7403 - loss: 1.3352
# Epoch 4/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7330 - loss: 1.3323
# Epoch 5/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7682 - loss: 1.3276
# Epoch 6/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7964 - loss: 1.3121
# Epoch 7/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7693 - loss: 1.3094
# Epoch 8/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7753 - loss: 1.3086
# Epoch 9/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7846 - loss: 1.3040
# Epoch 10/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7733 - loss: 1.3053

# %%
# Print results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, std, param))
# Out:
# Best: 0.809709 using {'batch_size': 64, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.801655 (0.019154) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.804340 (0.027202) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.807025 (0.024002) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.801655 (0.025241) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.801691 (0.032654) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.804340 (0.024037) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.804340 (0.020387) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.801655 (0.027951) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 32, 'model__activation': 'relu', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# ...
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 32, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l1', 'model__reg_rate': 0.1}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808367 (0.024431) with: {'batch_size': 64, 'model__activation': 'tanh', 'model__dropout_rate': 0.5, 'model__learning_rate': 0.1, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 64, 'model__reg_method': 'l2', 'model__reg_rate': 0.1}

# %% [markdown]
# ## iteration 2

# %% [markdown]
# going to stick w relu activation and no dropout (commented out in build function)

# %%
BINARY_CLASSIFICATION = True
BINARY_ENCODE_THRESHOLD = 4 # values greater than this will be encoded as 1

# %%
# Load dataset
X = data[features]

if BINARY_CLASSIFICATION:
    y = data['Depression_Score'].apply(lambda x: 1 if x > BINARY_ENCODE_THRESHOLD else 0)
else:
    y = data['Depression_Score']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=12, shuffle=True)

# Preprocess data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define parameters grid for grid search
param_grid = {
    # parameters for Sequential model
    'model__num_layers': [2, 3, 4], # number of hidden layers
    'model__num_neurons': [8, 10, 12],
    # 'model__dropout_rate': [0.2, 0.5],
    'model__momentum': [0.5, 0.9],
    'model__activation': ['relu'],
    'model__reg_method': ['l1', 'l2'],
    'model__reg_rate': [0.001, 0.01],
    'model__learning_rate': [0.001, 0.01],
    # parameters for KerasClassifier
    'batch_size': [32, 64]
}

# Create KerasClassifier wrapper for scikit-learn
model = KerasClassifier(build_fn=build_model, epochs=10, verbose=1)

# Perform grid search with cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=kfold, scoring='accuracy')
grid_result = grid_search.fit(X_train, y_train)
# Out:
# c:\repos\ECS171FQ24_ResearchProject_SATAK\.venv\Lib\site-packages\joblib\externals\loky\process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# c:\repos\ECS171FQ24_ResearchProject_SATAK\.venv\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\repos\ECS171FQ24_ResearchProject_SATAK\.venv\Lib\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# Epoch 1/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8121 - loss: 0.6751
# Epoch 2/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8398 - loss: 0.6589
# Epoch 3/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8630 - loss: 0.6398
# Epoch 4/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8899 - loss: 0.6216
# Epoch 5/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9076 - loss: 0.6018
# Epoch 6/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9079 - loss: 0.5873
# Epoch 7/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9076 - loss: 0.5724
# Epoch 8/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9014 - loss: 0.5590
# Epoch 9/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9127 - loss: 0.5441
# Epoch 10/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9099 - loss: 0.5329

# %%
# Print results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, std, param))
# Out:
# Best: 0.911499 using {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.894157 (0.026677) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.872582 (0.076356) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.837673 (0.117275) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.904823 (0.017201) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.824251 (0.133385) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.903445 (0.021179) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.895490 (0.024696) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.886157 (0.040260) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.911499 (0.021483) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.903445 (0.022013) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.895391 (0.032040) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.902103 (0.027479) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.890022 (0.047081) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.907490 (0.018280) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.907472 (0.020204) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.908814 (0.023188) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 32, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.845781 (0.088096) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.843043 (0.114645) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.871230 (0.069230) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.715526 (0.238562) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.616197 (0.263462) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.871230 (0.093961) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.551767 (0.309342) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.712841 (0.293146) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.722532 (0.165279) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.887338 (0.033383) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.775928 (0.173625) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.808412 (0.096007) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.754452 (0.307420) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.735660 (0.212935) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.681969 (0.293592) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.908814 (0.023188) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.866157 (0.078318) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.703463 (0.229761) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.730291 (0.314031) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.797405 (0.194225) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.817629 (0.148404) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.721593 (0.237190) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.906130 (0.028242) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.847069 (0.129880) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.908823 (0.019355) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.867204 (0.083724) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.834989 (0.169392) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.898157 (0.021192) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.855123 (0.107330) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.001, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# ...
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.5, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 2, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 3, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 8, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 10, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l1', 'model__reg_rate': 0.01}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.001}
# 0.910157 (0.020720) with: {'batch_size': 64, 'model__activation': 'relu', 'model__learning_rate': 0.01, 'model__momentum': 0.9, 'model__num_layers': 4, 'model__num_neurons': 12, 'model__reg_method': 'l2', 'model__reg_rate': 0.01}
